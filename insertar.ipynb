# %%
import pandas as pd

# %%
data = pd.read_excel('Metricos CDI_2026.xlsx', header=1, usecols= lambda x: 'unamed' not in str(x).lower())

# %%
data
# Out:
#    Proceso  Numero de Metrico  \
# 0      C04             1030.0
# 1      C03             1080.0
# 2      C04             1095.0
# 3      C04             1100.0
# 4      C04             1140.0
# 5      S01             1200.0
# 6      P01             1401.0
# 7      S01             1402.0
# 8      P01             1403.0
# 9      S01             1422.0
# 10     S10             2040.0
# 11     S10             2041.0
# 12     P02             2050.0
# 13     P02             2055.0
# 14     S10             2080.0
# 15     S10             2090.0
# 16     C02             2401.0
# 17     C02             2402.0
# 18     C02             2403.0
# 19     C02             2404.0
# 20     C02             2405.0
# 21     C02             2410.0
# 22     P02             2412.0
# 23     P02             2413.0
# 24     P02             2430.0
# 25     P02             2431.0
# 26     C02             2432.0
# 27     P02             2433.0
# 28     C04             4010.0
# 29     C04             4011.0
# ...

# %%
new_data = data[['Proceso','Nombre del Metrico', 'Numero de Metrico', 'Limite Amarillo', 'Limite Verde']].copy()

# %%
new_data
# Out:
#    Proceso                                 Nombre del Metrico  \
# 0      C04                  Average number of Claim per month
# 1      C03  PPAP validated on time according to customer P...
# 2      C04                 Daily Service Rate (OTD Negociado)
# 3      C04           Number of PPAP validated under deviation
# 4      C04                   Number of customer line stoppage
# 5      S01                        Supplier Service Rate (otd)
# 6      P01                                             EBITDA
# 7      S01                                 Net Purchase index
# 8      P01                                               NCFD
# 9      S01   Number of customer claim due to supplier failure
# 10     S10                                    Absence rate A1
# 11     S10                  Absence rate (ADT) Injustificadas
# 12     P02                  Number of occupationnal incidents
# 13     P02                         Number of Almost Incident
# ...

# %%
clean_data = new_data.dropna()

# %%
clean_data
# Out:
#    Proceso                                 Nombre del Metrico  \
# 0      C04                  Average number of Claim per month
# 1      C03  PPAP validated on time according to customer P...
# 2      C04                 Daily Service Rate (OTD Negociado)
# 3      C04           Number of PPAP validated under deviation
# 4      C04                   Number of customer line stoppage
# 5      S01                        Supplier Service Rate (otd)
# 7      S01                                 Net Purchase index
# 9      S01   Number of customer claim due to supplier failure
# 10     S10                                    Absence rate A1
# 11     S10                  Absence rate (ADT) Injustificadas
# 12     P02                  Number of occupationnal incidents
# 13     P02                         Number of Almost Incident
# 14     S10                                      Rotation Rate
# 15     S10                     Training plan achievement rate
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
clean_data
# Out:
#    Proceso                                 Nombre del Metrico  \
# 0      C04                  Average number of Claim per month
# 1      C03  PPAP validated on time according to customer P...
# 2      C04                 Daily Service Rate (OTD Negociado)
# 3      C04           Number of PPAP validated under deviation
# 4      C04                   Number of customer line stoppage
# 5      S01                        Supplier Service Rate (otd)
# 7      S01                                 Net Purchase index
# 9      S01   Number of customer claim due to supplier failure
# 10     S10                                    Absence rate A1
# 11     S10                  Absence rate (ADT) Injustificadas
# 12     P02                  Number of occupationnal incidents
# 13     P02                         Number of Almost Incident
# 14     S10                                      Rotation Rate
# 15     S10                     Training plan achievement rate
# ...

# %%
clean_data.to_csv('output.csv', index=False)

# %%
excel_ids = set(data["Numero de Metrico"].dropna().astype(int))

# %%
print(len(excel_ids))
print(sorted(excel_ids))
# Out:
# 83
# [1030, 1080, 1095, 1100, 1140, 1200, 1401, 1402, 1403, 1422, 2040, 2041, 2050, 2055, 2080, 2090, 2401, 2402, 2403, 2404, 2405, 2410, 2412, 2413, 2430, 2431, 2432, 2433, 4010, 4011, 4015, 4030, 4031, 4032, 4033, 4034, 4035, 4036, 4050, 4051, 4052, 4060, 4061, 4070, 4080, 4210, 4270, 4360, 4361, 4362, 4366, 4367, 4370, 4372, 4380, 4413, 4414, 4415, 4416, 4432, 4433, 4435, 4440, 4450, 4470, 4490, 4491, 4500, 4502, 4504, 4510, 4511, 4610, 4740, 5030, 5040, 5090, 9403, 9406, 10401, 10403, 10432, 10433]

# %%
clean_data[[
    "Numero de Metrico",
    "Limite Amarillo",
    "Limite Verde"
]].to_csv('output.csv', index=False)
